# %% [markdown]
# # **regression for adj and precursor**

# %%
data <- read.csv("data/dif_DNA/dataframe_2022_01_05_11_nonCoding_adj_precursor_results.csv")

# %%
summary(lm(data$trip_chnage~data$muts))
# Out:
# Call:
# lm(formula = data$trip_chnage ~ data$muts)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.84166 -0.37167 -0.08427  0.30787  1.39601
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.504e-01  7.293e-02   3.433  0.00107 **
# data$muts   -3.904e+03  6.649e+02  -5.871 1.83e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.484 on 62 degrees of freedom
# Multiple R-squared:  0.3573,	Adjusted R-squared:  0.347
# F-statistic: 34.47 on 1 and 62 DF,  p-value: 1.834e-07

# %%
log10(data$adj_mut)
# Out:
#  [1] -4.206826 -3.701330 -3.775650 -4.755101 -4.161289 -4.591942 -4.119239
#  [8] -4.526025 -4.635360 -4.674575 -4.237923 -4.603668 -4.595713 -4.132015
# [15] -4.232611 -3.770708 -4.534494 -4.610866 -4.284353 -4.170446 -4.656479
# [22] -4.232276 -4.710205 -3.980392 -4.231000 -4.641090 -4.489712 -4.013644
# [29] -4.731035 -4.589764 -4.237785 -4.497788 -4.728305 -4.487179 -4.549741
# [36] -4.638424 -4.117185 -3.703422 -3.798543 -4.243940 -3.804089 -4.015260
# [43] -4.134343 -4.534303 -4.160743 -4.492229 -4.208039 -4.611590 -4.707898
# [50] -4.267723 -4.497831 -4.254995 -4.635008 -4.179033 -3.796345 -4.221474
# [57] -4.502101 -4.539511 -4.218523 -3.989875 -4.239510 -3.798512 -4.528261
# [64] -4.734432

# %%
summary(lm(data$trip_chnage~data$muts+log10(data$adj_mut)))
# Out:
# Call:
# lm(formula = data$trip_chnage ~ data$muts + log10(data$adj_mut))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.74544 -0.21762 -0.00827  0.21519  0.91127
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)           -6.8288     0.8573  -7.965 5.05e-11 ***
# data$muts           -304.6122   633.3683  -0.481    0.632
# log10(data$adj_mut)   -1.5866     0.1918  -8.272 1.50e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.335 on 61 degrees of freedom
# Multiple R-squared:  0.6971,	Adjusted R-squared:  0.6872
# F-statistic: 70.19 on 2 and 61 DF,  p-value: < 2.2e-16

# %%
summary(lm(data$trip_chnage~data$muts_log10+data$precursor_mut+data$adj_mut))
# Out:
# Call:
# lm(formula = data$trip_chnage ~ data$muts_log10 + data$precursor_mut +
#     data$adj_mut)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.68520 -0.28697  0.04149  0.17215  1.16338
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)         3.808e-01  1.059e+00   0.359    0.720
# data$muts_log10    -1.940e-02  9.471e-02  -0.205    0.838
# data$precursor_mut  2.079e+02  1.748e+03   0.119    0.906
# data$adj_mut       -9.356e+03  1.735e+03  -5.392 1.24e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3886 on 60 degrees of freedom
# Multiple R-squared:  0.5991,	Adjusted R-squared:  0.5791
# F-statistic: 29.89 on 3 and 60 DF,  p-value: 6.03e-12
